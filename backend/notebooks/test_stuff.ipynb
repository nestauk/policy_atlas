# %%
# !uv pip list
# Out:
# Using Python 3.12.2 environment at: /Users/rosie.oxbury/Documents/git_repos/policy_atlas/.venv
# Package                                  Version         Editable project location
# ---------------------------------------- --------------- ----------------------------------------------------
# alembic                                  1.18.4
# annotated-doc                            0.0.4
# annotated-types                          0.7.0
# anyio                                    4.14.0
# appnope                                  0.1.4
# ast-serialize                            0.5.0
# asttokens                                3.0.2
# babel                                    2.18.0
# backoff                                  2.2.1
# certifi                                  2026.6.17
# charset-normalizer                       3.4.7
# click                                    8.4.2
# comm                                     0.2.3
# courlan                                  1.4.0
# ...

# %%
# !uv add pandas --project /Users/rosie.oxbury/Documents/git_repos/policy_atlas/backend
# Out:
# ...
# Resolved 127 packages in 0.88ms
# Audited 113 packages in 0.52ms

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'
